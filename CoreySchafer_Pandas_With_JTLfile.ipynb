# %% [markdown]
# # Part 1

# %%
import pandas as pd

# %%
df=pd.read_csv('D:/Projects/ICON2/02_Feb_12/DataPreparation_02_ResultStatusActionHandler.jtl')

# %%
df
# Out:
#           timeStamp  elapsed  \
# 0     1613114173097     2825
# 1     1613114173097       14
# 2     1613114173113       28
# 3     1613114173114       40
# 4     1613114173115       31
# ...             ...      ...
# 3389  1613117755620    27619
# 3390  1613117768244    16396
# 3391  1613117763007    23692
# 3392  1613117763861    24907
# 3393  1613117772279    16548
#
#                                                   label  responseCode  \
# 0                                   001_ISMSAccessURL-0         200.0
# 1                     https://icon.internal.local/login         200.0
# 2     https://icon.internal.local/assets/img/ICA_log...         200.0
# 3         https://icon.internal.local/runtime-es2015.js         200.0
# 4            https://icon.internal.local/runtime-es5.js         200.0
# ...                                                 ...           ...
# 3389                      BP01_WL_TX04_ClickOnCreate-06         200.0
# ...

# %%
df.shape
# Out:
# (3394, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3394 entries, 0 to 3393
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timeStamp        3394 non-null   int64
#  1   elapsed          3394 non-null   int64
#  2   label            3394 non-null   object
#  3   responseCode     3304 non-null   float64
#  4   responseMessage  3238 non-null   object
#  5   threadName       3394 non-null   object
#  6   dataType         2733 non-null   object
#  7   success          3394 non-null   bool
#  8   failureMessage   0 non-null      float64
#  9   bytes            3394 non-null   int64
#  10  sentBytes        3394 non-null   int64
#  11  grpThreads       3394 non-null   int64
#  12  allThreads       3394 non-null   int64
#  13  URL              2818 non-null   object
#  14  Latency          3394 non-null   int64
#  15  IdleTime         3394 non-null   int64
#  16  Connect          3394 non-null   int64
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',200)

# %%
df.head(10)
# Out:
#        timeStamp  elapsed                                              label  \
# 0  1613114173097     2825                                001_ISMSAccessURL-0
# 1  1613114173097       14                  https://icon.internal.local/login
# 2  1613114173113       28  https://icon.internal.local/assets/img/ICA_log...
# 3  1613114173114       40      https://icon.internal.local/runtime-es2015.js
# 4  1613114173115       31         https://icon.internal.local/runtime-es5.js
# 5  1613114173115      326       https://icon.internal.local/polyfills-es5.js
# 6  1613114173115      146    https://icon.internal.local/polyfills-es2015.js
# 7  1613114173115      265       https://icon.internal.local/styles-es2015.js
# 8  1613114173141      222          https://icon.internal.local/styles-es5.js
# 9  1613114173146     1223             https://icon.internal.local/scripts.js
#
#    responseCode responseMessage        threadName dataType  success  \
# ...

# %%
df.tail(10)
# Out:
#           timeStamp  elapsed                               label  \
# 3384  1613117744491    23871  BP01_WL_TX02_WL_SelectIncidentType
# 3385  1613117772332       36          BP01_WL_TX03_WL_ChooseFile
# 3386  1613117770417       39          BP01_WL_TX03_WL_ChooseFile
# 3387  1613117738357    35883    BP01_WL_TX01_IncidentCreation-08
# 3388  1613117742028    33993       BP01_WL_TX04_ClickOnCreate-05
# 3389  1613117755620    27619       BP01_WL_TX04_ClickOnCreate-06
# 3390  1613117768244    16396       BP01_WL_TX04_ClickOnCreate-06
# 3391  1613117763007    23692       BP01_WL_TX04_ClickOnCreate-00
# 3392  1613117763861    24907       BP01_WL_TX04_ClickOnCreate-00
# 3393  1613117772279    16548    BP01_WL_Tx05_EnterRemart_Close-2
#
#       responseCode                                    responseMessage  \
# 3384         200.0  Number of samples in transaction : 3, number o...
# 3385         200.0  Number of samples in transaction : 2, number o...
# ...

# %%
df['URL']
# Out:
# 0                       https://icon.internal.local/login
# 1                       https://icon.internal.local/login
# 2       https://icon.internal.local/assets/img/ICA_log...
# 3           https://icon.internal.local/runtime-es2015.js
# 4              https://icon.internal.local/runtime-es5.js
#                               ...
# 3389    https://icon.internal.local/ECHO/ims/v0/WL/inc...
# 3390    https://icon.internal.local/ECHO/ims/v0/WL/inc...
# 3391    https://icon.internal.local/ECHO/ims/v0/WL/inc...
# 3392    https://icon.internal.local/ECHO/ims/v0/WL/inc...
# 3393    https://icon.internal.local/ECHO/ims/v0/WL/inc...
# Name: URL, Length: 3394, dtype: object

# %%
type(df['URL'])
# Out:
# pandas.core.series.Series

# %%
df[['timeStamp','elapsed','label','ThreadID']]
# Out:
#           timeStamp  elapsed  \
# 0     1613114173097     2825
# 1     1613114173097       14
# 2     1613114173113       28
# 3     1613114173114       40
# 4     1613114173115       31
# ...             ...      ...
# 3389  1613117755620    27619
# 3390  1613117768244    16396
# 3391  1613117763007    23692
# 3392  1613117763861    24907
# 3393  1613117772279    16548
#
#                                                   label  ThreadID
# 0                                   001_ISMSAccessURL-0         1
# 1                     https://icon.internal.local/login         1
# 2     https://icon.internal.local/assets/img/ICA_log...         1
# 3         https://icon.internal.local/runtime-es2015.js         1
# 4            https://icon.internal.local/runtime-es5.js         1
# ...                                                 ...       ...
# 3389                      BP01_WL_TX04_ClickOnCreate-06         6
# 3390                      BP01_WL_TX04_ClickOnCreate-06        10
# ...

# %%
df.columns
# Out:
# Index(['timeStamp', 'elapsed', 'label', 'responseCode', 'responseMessage',
#        'threadName', 'dataType', 'success', 'failureMessage', 'bytes',
#        'sentBytes', 'grpThreads', 'allThreads', 'URL', 'Latency', 'IdleTime',
#        'Connect', 'ThreadID', 'IncidentType', 'CheckPoint', 'IncidentID',
#        'CASSReqID', 'VOIPltNo'],
#       dtype='object')

# %%
df.iloc[3000]
# Out:
# timeStamp                                              1613117239983
# elapsed                                                        19358
# label                               BP01_WL_TX01_IncidentCreation-03
# responseCode                                                     200
# responseMessage                                                   OK
# threadName                                          Thread Group 1-1
# dataType                                                        text
# success                                                         True
# failureMessage                                                   NaN
# bytes                                                            933
# sentBytes                                                       3572
# grpThreads                                                        10
# allThreads                                                        10
# URL                https://icon.internal.local/ECHO/ims/v0/WL/inc...
# ...

# %%
df.iloc[[3000,3001]]
# Out:
#           timeStamp  elapsed                             label  responseCode  \
# 3000  1613117239983    19358  BP01_WL_TX01_IncidentCreation-03         200.0
# 3001  1613117259341        5  BP01_WL_TX01_IncidentCreation-04         200.0
#
#      responseMessage        threadName dataType  success  failureMessage  \
# 3000              OK  Thread Group 1-1     text     True             NaN
# 3001              OK  Thread Group 1-1     text     True             NaN
#
#       bytes  sentBytes  grpThreads  allThreads  \
# 3000    933       3572          10          10
# 3001  22925       3462          10          10
#
#                                                     URL  Latency  IdleTime  \
# 3000  https://icon.internal.local/ECHO/ims/v0/WL/inc...    19358         0
# 3001  https://icon.internal.local/assets/json/incide...        5         0
#
#       Connect  ThreadID  IncidentType  CheckPoint  IncidentID  CASSReqID  \
# ...

# %%
df.iloc[[3000,3001],2]
# Out:
# 3000    BP01_WL_TX01_IncidentCreation-03
# 3001    BP01_WL_TX01_IncidentCreation-04
# Name: label, dtype: object

# %%
df.iloc[[3000,3001],[1,2]]
# Out:
#       elapsed                             label
# 3000    19358  BP01_WL_TX01_IncidentCreation-03
# 3001        5  BP01_WL_TX01_IncidentCreation-04

# %%
df.loc[3000] # Bcz index is not yet set
# Out:
# timeStamp                                              1613117239983
# elapsed                                                        19358
# label                               BP01_WL_TX01_IncidentCreation-03
# responseCode                                                     200
# responseMessage                                                   OK
# threadName                                          Thread Group 1-1
# dataType                                                        text
# success                                                         True
# failureMessage                                                   NaN
# bytes                                                            933
# sentBytes                                                       3572
# grpThreads                                                        10
# allThreads                                                        10
# URL                https://icon.internal.local/ECHO/ims/v0/WL/inc...
# ...

# %%
df.loc[[3000,3001]] #Option 1
# Out:
#           timeStamp  elapsed                             label  responseCode  \
# 3000  1613117239983    19358  BP01_WL_TX01_IncidentCreation-03         200.0
# 3001  1613117259341        5  BP01_WL_TX01_IncidentCreation-04         200.0
#
#      responseMessage        threadName dataType  success  failureMessage  \
# 3000              OK  Thread Group 1-1     text     True             NaN
# 3001              OK  Thread Group 1-1     text     True             NaN
#
#       bytes  sentBytes  grpThreads  allThreads  \
# 3000    933       3572          10          10
# 3001  22925       3462          10          10
#
#                                                     URL  Latency  IdleTime  \
# 3000  https://icon.internal.local/ECHO/ims/v0/WL/inc...    19358         0
# 3001  https://icon.internal.local/assets/json/incide...        5         0
#
#       Connect  ThreadID  IncidentType  CheckPoint  IncidentID  CASSReqID  \
# ...

# %%
df.loc[3000:3002] # Option 2 Alternative method
# Out:
#           timeStamp  elapsed                             label  responseCode  \
# 3000  1613117239983    19358  BP01_WL_TX01_IncidentCreation-03         200.0
# 3001  1613117259341        5  BP01_WL_TX01_IncidentCreation-04         200.0
# 3002  1613117259346       71  BP01_WL_TX01_IncidentCreation-05         200.0
#
#      responseMessage        threadName dataType  success  failureMessage  \
# 3000              OK  Thread Group 1-1     text     True             NaN
# 3001              OK  Thread Group 1-1     text     True             NaN
# 3002              OK  Thread Group 1-1     text     True             NaN
#
#       bytes  sentBytes  grpThreads  allThreads  \
# 3000    933       3572          10          10
# 3001  22925       3462          10          10
# 3002   1724       3455          10          10
#
#                                                     URL  Latency  IdleTime  \
# 3000  https://icon.internal.local/ECHO/ims/v0/WL/inc...    19358         0
# ...

# %%
df.loc[[3000,3001],'label']
# Out:
# 3000    BP01_WL_TX01_IncidentCreation-03
# 3001    BP01_WL_TX01_IncidentCreation-04
# Name: label, dtype: object

# %%
df.loc[[3000,3001],['elapsed','label']] #Option 1
# Out:
#       elapsed                             label
# 3000    19358  BP01_WL_TX01_IncidentCreation-03
# 3001        5  BP01_WL_TX01_IncidentCreation-04

# %%
df.loc[3000:3005,'responseCode':'success'] #Option 2 Alternative method
# Out:
#       responseCode                                    responseMessage  \
# 3000         200.0                                                 OK
# 3001         200.0                                                 OK
# 3002         200.0                                                 OK
# 3003         200.0                                                 OK
# 3004         504.0                                   Gateway Time-out
# 3005           NaN  Number of samples in transaction : 1, number o...
#
#             threadName dataType  success
# 3000  Thread Group 1-1     text     True
# 3001  Thread Group 1-1     text     True
# 3002  Thread Group 1-1     text     True
# 3003  Thread Group 1-1     text     True
# 3004  Thread Group 1-8     text    False
# 3005  Thread Group 1-8      NaN    False

# %%
df['responseCode'].value_counts()
# Out:
# 200.0    3119
# 504.0      89
# 202.0      85
# 502.0       7
# 500.0       4
# Name: responseCode, dtype: int64

# %%
df.set_index('timeStamp',inplace=True)
#df.reset_index('timeStamp',inplace=True)
#df.sort_index()
#df.sort_index(ascending=False)
#df.sort_index(inplace=True)

# %%
df.head(5)
# Out:
#                elapsed                                              label  \
# timeStamp
# 1613114173097     2825                                001_ISMSAccessURL-0
# 1613114173097       14                  https://icon.internal.local/login
# 1613114173113       28  https://icon.internal.local/assets/img/ICA_log...
# 1613114173114       40      https://icon.internal.local/runtime-es2015.js
# 1613114173115       31         https://icon.internal.local/runtime-es5.js
#
#                responseCode responseMessage        threadName dataType  \
# timeStamp
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173113         200.0              OK  Thread Group 1-1      bin
# 1613114173114         200.0              OK  Thread Group 1-1     text
# 1613114173115         200.0              OK  Thread Group 1-1     text
#
# ...

# %%
df.index
# Out:
# Int64Index([1613114173097, 1613114173097, 1613114173113, 1613114173114,
#             1613114173115, 1613114173115, 1613114173115, 1613114173115,
#             1613114173141, 1613114173146,
#             ...
#             1613117744491, 1613117772332, 1613117770417, 1613117738357,
#             1613117742028, 1613117755620, 1613117768244, 1613117763007,
#             1613117763861, 1613117772279],
#            dtype='int64', name='timeStamp', length=3394)

# %%
df.loc[1613114173113,'responseCode']
# Out:
# 200.0

# %%
df.iloc[2,2]#Note the second "2" is column index. iloc we cant use colume name only column index
# Out:
# 200.0

# %%
df.loc[1613114173113 ,'URL']# To avoid the '...' elipses
# Out:
# 'https://icon.internal.local/assets/img/ICA_logo.png'

# %%
df.head(5)
# Out:
#                elapsed                                              label  \
# timeStamp
# 1613114173097     2825                                001_ISMSAccessURL-0
# 1613114173097       14                  https://icon.internal.local/login
# 1613114173113       28  https://icon.internal.local/assets/img/ICA_log...
# 1613114173114       40      https://icon.internal.local/runtime-es2015.js
# 1613114173115       31         https://icon.internal.local/runtime-es5.js
#
#                responseCode responseMessage        threadName dataType  \
# timeStamp
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173113         200.0              OK  Thread Group 1-1      bin
# 1613114173114         200.0              OK  Thread Group 1-1     text
# 1613114173115         200.0              OK  Thread Group 1-1     text
#
# ...

# %%
#filt = (df['URL']=='null')
#filt

# %%
filt=pd.isnull(df['URL'])
filt
# Out:
# timeStamp
# 1613114173097    False
# 1613114173097    False
# 1613114173113    False
# 1613114173114    False
# 1613114173115    False
#                  ...
# 1613117755620    False
# 1613117768244    False
# 1613117763007    False
# 1613117763861    False
# 1613117772279    False
# Name: URL, Length: 3394, dtype: bool

# %%
df[filt] # Option 1
# Out:
#                elapsed                               label  responseCode  \
# timeStamp
# 1613114173095     2856                   001_ISMSAccessURL         200.0
# 1613114180981     4888                       002_ISMSLogin         200.0
# 1613114183095     2901                   001_ISMSAccessURL         200.0
# 1613114191069     4780                       002_ISMSLogin         200.0
# 1613114193096     2873                   001_ISMSAccessURL         200.0
# ...                ...                                 ...           ...
# 1613117742803    22612  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117743994    23337  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117744491    23871  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117772332       36          BP01_WL_TX03_WL_ChooseFile         200.0
# 1613117770417       39          BP01_WL_TX03_WL_ChooseFile         200.0
#
#                                                  responseMessage  \
# timeStamp
# ...

# %%
df.loc[filt] # Option 2 The advantage is we can filter using columns
# Out:
#                elapsed                               label  responseCode  \
# timeStamp
# 1613114173095     2856                   001_ISMSAccessURL         200.0
# 1613114180981     4888                       002_ISMSLogin         200.0
# 1613114183095     2901                   001_ISMSAccessURL         200.0
# 1613114191069     4780                       002_ISMSLogin         200.0
# 1613114193096     2873                   001_ISMSAccessURL         200.0
# ...                ...                                 ...           ...
# 1613117742803    22612  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117743994    23337  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117744491    23871  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117772332       36          BP01_WL_TX03_WL_ChooseFile         200.0
# 1613117770417       39          BP01_WL_TX03_WL_ChooseFile         200.0
#
#                                                  responseMessage  \
# timeStamp
# ...

# %%
df.loc[filt,'responseCode'] # Option 2 The advantage is we can filter using columns
# Out:
# timeStamp
# 1613114173095    200.0
# 1613114180981    200.0
# 1613114183095    200.0
# 1613114191069    200.0
# 1613114193096    200.0
#                  ...
# 1613117742803    200.0
# 1613117743994    200.0
# 1613117744491    200.0
# 1613117772332    200.0
# 1613117770417    200.0
# Name: responseCode, Length: 576, dtype: float64

# %%
df.loc[filt,['label','responseCode']] # Option 2 The advantage is we can filter using columns
# Out:
#                                             label  responseCode
# timeStamp
# 1613114173095                   001_ISMSAccessURL         200.0
# 1613114180981                       002_ISMSLogin         200.0
# 1613114183095                   001_ISMSAccessURL         200.0
# 1613114191069                       002_ISMSLogin         200.0
# 1613114193096                   001_ISMSAccessURL         200.0
# ...                                           ...           ...
# 1613117742803  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117743994  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117744491  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117772332          BP01_WL_TX03_WL_ChooseFile         200.0
# 1613117770417          BP01_WL_TX03_WL_ChooseFile         200.0
#
# [576 rows x 2 columns]

# %%
df_TC=df.loc[filt]
df_TC
# Out:
#                elapsed                               label  responseCode  \
# timeStamp
# 1613114173095     2856                   001_ISMSAccessURL         200.0
# 1613114180981     4888                       002_ISMSLogin         200.0
# 1613114183095     2901                   001_ISMSAccessURL         200.0
# 1613114191069     4780                       002_ISMSLogin         200.0
# 1613114193096     2873                   001_ISMSAccessURL         200.0
# ...                ...                                 ...           ...
# 1613117742803    22612  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117743994    23337  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117744491    23871  BP01_WL_TX02_WL_SelectIncidentType         200.0
# 1613117772332       36          BP01_WL_TX03_WL_ChooseFile         200.0
# 1613117770417       39          BP01_WL_TX03_WL_ChooseFile         200.0
#
#                                                  responseMessage  \
# timeStamp
# ...

# %%
df_TC['success'].value_counts()
# Out:
# True     486
# False     90
# Name: success, dtype: int64

# %%
df_http_req=df.loc[~filt]
df_http_req.head(5)
# Out:
#                elapsed                                              label  \
# timeStamp
# 1613114173097     2825                                001_ISMSAccessURL-0
# 1613114173097       14                  https://icon.internal.local/login
# 1613114173113       28  https://icon.internal.local/assets/img/ICA_log...
# 1613114173114       40      https://icon.internal.local/runtime-es2015.js
# 1613114173115       31         https://icon.internal.local/runtime-es5.js
#
#                responseCode responseMessage        threadName dataType  \
# timeStamp
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173113         200.0              OK  Thread Group 1-1      bin
# 1613114173114         200.0              OK  Thread Group 1-1     text
# 1613114173115         200.0              OK  Thread Group 1-1     text
#
# ...

# %%
filt_fail_txn=(df_TC['label']=='BP01_WL_TX04_ClickOnCreate') & (df_TC['responseCode']!=200)
df_TC[filt_fail_txn].shape
# Out:
# (23, 22)

# %%
df_http_req['success'].value_counts()
# Out:
# True     2718
# False     100
# Name: success, dtype: int64

# %%
df_http_req['responseMessage'].value_counts()
# Out:
# OK                       2477
# Gateway Time-out           89
# Accepted                   85
# Bad Gateway                 7
# Internal Server Error       4
# Name: responseMessage, dtype: int64

# %%
df_TC['responseMessage'].value_counts()
# Out:
# Number of samples in transaction : 2, number of failing samples : 0     116
# Number of samples in transaction : 3, number of failing samples : 0     116
# Number of samples in transaction : 11, number of failing samples : 0    113
# Number of samples in transaction : 9, number of failing samples : 0      86
# Number of samples in transaction : 1, number of failing samples : 1      57
# Number of samples in transaction : 4, number of failing samples : 0      35
# Number of samples in transaction : 6, number of failing samples : 1      10
# Number of samples in transaction : 8, number of failing samples : 0      10
# Number of samples in transaction : 5, number of failing samples : 0      10
# Number of samples in transaction : 9, number of failing samples : 1       9
# Number of samples in transaction : 11, number of failing samples : 1      4
# Number of samples in transaction : 4, number of failing samples : 1       3
# ...

# %%
df_http_req['failureMessage'].value_counts()
# Out:
# Series([], Name: failureMessage, dtype: int64)

# %%
df_TC['failureMessage'].value_counts()
# Out:
# Series([], Name: failureMessage, dtype: int64)

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse1=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==1)
df_vuser1=df_responseTimeOver_vuser[filt_vuse1]
df_vuser1.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse2=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==2)
df_vuser2=df_responseTimeOver_vuser[filt_vuse2]
df_vuser2.count()
# Out:
# elapsed     12
# label       12
# ThreadID    12
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse3=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==3)
df_vuser3=df_responseTimeOver_vuser[filt_vuse3]
df_vuser3.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse4=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==4)
df_vuser4=df_responseTimeOver_vuser[filt_vuse4]
df_vuser4.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse5=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==5)
df_vuser5=df_responseTimeOver_vuser[filt_vuse5]
df_vuser5.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse6=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==6)
df_vuser6=df_responseTimeOver_vuser[filt_vuse6]
df_vuser6.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse7=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==7)
df_vuser7=df_responseTimeOver_vuser[filt_vuse7]
df_vuser7.count()
# Out:
# elapsed     10
# label       10
# ThreadID    10
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse8=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==8)
df_vuser8=df_responseTimeOver_vuser[filt_vuse8]
df_vuser8.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse9=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==9)
df_vuser9=df_responseTimeOver_vuser[filt_vuse9]
df_vuser9.count()
# Out:
# elapsed     11
# label       11
# ThreadID    11
# dtype: int64

# %%
df_responseTimeOver_vuser=df_TC[['elapsed','label','ThreadID']]
filt_vuse10=(df_responseTimeOver_vuser['label']=='BP01_WL_TX04_ClickOnCreate') & (df_responseTimeOver_vuser['ThreadID']==10)
df_vuser10=df_responseTimeOver_vuser[filt_vuse10]
df_vuser10.count()
# Out:
# elapsed     10
# label       10
# ThreadID    10
# dtype: int64

# %%
#df.set_index('timeStamp',inplace=True)
#df.reset_index('timeStamp',inplace=True)
#df.sort_index()
#df.sort_index(ascending=False)
#df.sort_index(inplace=True)
df_temp=df_TC[['elapsed','label','ThreadID']]

# %%
df_temp.reset_index('timeStamp',inplace=True)

# %%
df_temp
# Out:
#          timeStamp  elapsed                               label  ThreadID
# 0    1613114173095     2856                   001_ISMSAccessURL         1
# 1    1613114180981     4888                       002_ISMSLogin         1
# 2    1613114183095     2901                   001_ISMSAccessURL         2
# 3    1613114191069     4780                       002_ISMSLogin         2
# 4    1613114193096     2873                   001_ISMSAccessURL         3
# ..             ...      ...                                 ...       ...
# 571  1613117742803    22612  BP01_WL_TX02_WL_SelectIncidentType         8
# 572  1613117743994    23337  BP01_WL_TX02_WL_SelectIncidentType         3
# 573  1613117744491    23871  BP01_WL_TX02_WL_SelectIncidentType         2
# 574  1613117772332       36          BP01_WL_TX03_WL_ChooseFile         3
# 575  1613117770417       39          BP01_WL_TX03_WL_ChooseFile         8
#
# [576 rows x 4 columns]

# %%
filt_create=(df_temp['label']=='BP01_WL_TX04_ClickOnCreate')

# %%
df_create=df_temp[filt_create]
df_create
# Out:
#          timeStamp  elapsed                       label  ThreadID
# 28   1613114215110    40274  BP01_WL_TX04_ClickOnCreate         1
# 42   1613114226743    78186  BP01_WL_TX04_ClickOnCreate         2
# 52   1613114241487    94773  BP01_WL_TX04_ClickOnCreate         3
# 55   1613114258039   106077  BP01_WL_TX04_ClickOnCreate         4
# 57   1613114282276    99988  BP01_WL_TX04_ClickOnCreate         5
# ..             ...      ...                         ...       ...
# 542  1613117392763   196630  BP01_WL_TX04_ClickOnCreate         5
# 543  1613117397857   192438  BP01_WL_TX04_ClickOnCreate         8
# 545  1613117401790   191838  BP01_WL_TX04_ClickOnCreate         3
# 547  1613117417497   182712  BP01_WL_TX04_ClickOnCreate         2
# 560  1613117526339   186512  BP01_WL_TX04_ClickOnCreate         9
#
# [109 rows x 4 columns]

# %%
pd.set_option('display.max_rows',200)

# %%
df_create.pivot(index="timeStamp",columns="ThreadID",values="elapsed")
# Out:
# ThreadID             1         2         3         4         5         6   \
# timeStamp
# 1613114215110   40274.0       NaN       NaN       NaN       NaN       NaN
# 1613114226743       NaN   78186.0       NaN       NaN       NaN       NaN
# 1613114241487       NaN       NaN   94773.0       NaN       NaN       NaN
# 1613114258039       NaN       NaN       NaN  106077.0       NaN       NaN
# 1613114282276       NaN       NaN       NaN       NaN   99988.0       NaN
# 1613114303113       NaN       NaN       NaN       NaN       NaN   97499.0
# 1613114321178       NaN       NaN       NaN       NaN       NaN       NaN
# 1613114326974       NaN       NaN       NaN       NaN       NaN       NaN
# 1613114337722       NaN       NaN       NaN       NaN       NaN       NaN
# 1613114342450       NaN       NaN       NaN       NaN       NaN       NaN
# 1613114398110  101933.0       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df_http_req.head(5)
# Out:
#                elapsed                                              label  \
# timeStamp
# 1613114173097     2825                                001_ISMSAccessURL-0
# 1613114173097       14                  https://icon.internal.local/login
# 1613114173113       28  https://icon.internal.local/assets/img/ICA_log...
# 1613114173114       40      https://icon.internal.local/runtime-es2015.js
# 1613114173115       31         https://icon.internal.local/runtime-es5.js
#
#                responseCode responseMessage        threadName dataType  \
# timeStamp
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173097         200.0              OK  Thread Group 1-1     text
# 1613114173113         200.0              OK  Thread Group 1-1      bin
# 1613114173114         200.0              OK  Thread Group 1-1     text
# 1613114173115         200.0              OK  Thread Group 1-1     text
#
# ...

# %%
df_http_req['responseMessage'].value_counts()
# Out:
# OK                       2477
# Gateway Time-out           89
# Accepted                   85
# Bad Gateway                 7
# Internal Server Error       4
# Name: responseMessage, dtype: int64

# %%
df_http_req['responseCode'].value_counts()
# Out:
# 200.0    2633
# 504.0      89
# 202.0      85
# 502.0       7
# 500.0       4
# Name: responseCode, dtype: int64

# %%
filt_error=(df_http_req['responseCode']!=200) & (df_http_req['responseCode']!=202)
df_error=df_http_req[filt_error]
df_error
# Out:
#                elapsed                                  label  responseCode  \
# timeStamp
# 1613114706969    60003          BP01_WL_TX04_ClickOnCreate-05         504.0
# 1613114747102    60003          BP01_WL_TX04_ClickOnCreate-05         504.0
# 1613114884751    60003          BP01_WL_TX04_ClickOnCreate-05         504.0
# 1613115260410    60003          BP01_WL_TX04_ClickOnCreate-05         504.0
# 1613115338746    29400       BP01_WL_Tx05_EnterRemart_Close-2         500.0
# 1613115308804    60020       BP01_WL_Tx05_EnterRemart_Close-1         504.0
# 1613115309051    60018  BP01_WL_TX02_WL_SelectIncidentType-01         504.0
# 1613115322400    60005          BP01_WL_TX04_ClickOnCreate-00         504.0
# 1613115382404    15590          BP01_WL_TX04_ClickOnCreate-01         502.0
# 1613115345037    60003       BP01_WL_TX01_IncidentCreation-08         504.0
# 1613115377757    28384          BP01_WL_TX04_ClickOnCreate-00         502.0
# ...
